# %% [markdown]
# ### API

# %% [markdown]
# #### retreive most popular movies from IMDB website

# %%
#Load the API key from .env file
# %pip install python-dotenv requests
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in d:\teju\adv python\repository\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (2025.1.31)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the API key from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("API_KEY")

# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

querystring = {"limit":"20","topMeterTitlesType":"ALL"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "imdb232.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

api_data = response.json()

# %% [markdown]
# #### From the above API output, I want to extract most popular movie details
# title of the movie
#
# release year
#
# current rank

# %%
api_data
# Out:
# {'data': {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#       'id': 'tt3581920',
#       'titleText': {'text': 'The Last of Us', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Last of Us', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2023,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 1,
#        'day': 15,
#        'year': 2023,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2670496002',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWI3ODJlMzktY2U5NC00ZjdlLWE1MGItNWQxZDk3NWNjN2RhXkEyXkFqcGc@._V1_.jpg',
#        'height': 2048,
#        'width': 1383},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt20969586',
#       'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1321045250',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNDIzNGUwZmYtODM0Yy00NjA3LTgxOGUtOTY0ZGM5MjBkM2I3XkEyXkFqcGc@._V1_.jpg',
#        'height': 2500,
#        'width': 1688},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt9253284',
#       'titleText': {'text': 'Andor', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Andor', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 9,
#        'day': 21,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2931132418',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNGI2MTJjMjUtMTJhOC00YTY2LTg1NjUtMTdmMjg4YTk2YjM5XkEyXkFqcGc@._V1_.jpg',
#        'height': 2500,
#        'width': 1688},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30826447',
#       'titleText': {'text': 'The Four Seasons', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Four Seasons',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 1,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm83329794',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMjZiMDNhZWItZDk1YS00M2UyLTkxN2YtNDQ3ZmJjYTA4MzgwXkEyXkFqcGc@._V1_.jpg',
#        'height': 471,
#        'width': 318},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31193180',
#       'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 18,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm448960002',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt2085059',
#       'titleText': {'text': 'Black Mirror', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Black Mirror', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2011,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 12,
#        'day': 4,
#        'year': 2011,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1585480194',
#        'url': 'https://m.media-amazon.com/images/M/MV5BODcxMWI2NDMtYTc3NC00OTZjLWFmNmUtM2NmY2I1ODkxYzczXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31510819',
#       'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 30,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3806167042',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZDVmMzJkOWUtMjdjMi00NzA4LTgxMTItYjA4NjVjZDI0ZWU1XkEyXkFqcGc@._V1_.jpg',
#        'height': 1500,
#        'width': 1000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7335184',
#       'titleText': {'text': 'You', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'You', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2018,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 9,
#        'day': 9,
#        'year': 2018,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1658556418',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMTVlYmRhMWQtNmE0Yi00ODM1LWEzMWEtNTQzZGZhODRmZTE0XkEyXkFqcGc@._V1_.jpg',
#        'height': 1778,
#        'width': 1200},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt28309594',
#       'titleText': {'text': 'Nonnas', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Nonnas', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 9,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1138721282',
#        'url': 'https://m.media-amazon.com/images/M/MV5BODM0M2M4YWQtMzhlNy00NjdkLWFkODktOGNlNTc4OTFiZjZmXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 713}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt27740241',
#       'titleText': {'text': 'The Eternaut', 'isOriginalTitle': False},
#       'originalTitleText': {'text': 'El Eternauta', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 30,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2354348546',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYmIxZDczYjMtODQ0OS00YzQ2LWJhYjMtNjUwNTdjZTU4MDBjXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt20215234',
#       'titleText': {'text': 'Conclave', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Conclave', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2024,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 10,
#        'day': 25,
#        'year': 2024,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1139696129',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYjgxMDI5NmMtNTU3OS00ZDQxLTgxZmEtNzY1ZTBmMDY4NDRkXkEyXkFqcGc@._V1_.jpg',
#        'height': 1600,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13406094',
#       'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The White Lotus',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm437293314',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31434639',
#       'titleText': {'text': 'Warfare', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Warfare', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1897565186',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYzEyYjE1NmEtOTFmNy00ZmQxLThlYzctOGRjNmQ0N2VjMmNmXkEyXkFqcGc@._V1_.jpg',
#        'height': 2880,
#        'width': 1944},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 11}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14269590',
#       'titleText': {'text': 'Poker Face', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Poker Face', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2023,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 1,
#        'day': 26,
#        'year': 2023,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm154304770',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmEwZWEyMTktMmVmMy00YjE4LWEzNWEtMjc2Zjk5NWM3MjkxXkEyXkFqcGc@._V1_.jpg',
#        'height': 755,
#        'width': 510},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 9,
#        'rankChange': {'changeDirection': 'UP', 'difference': 72}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt5834204',
#       'titleText': {'text': "The Handmaid's Tale", 'isOriginalTitle': True},
#       'originalTitleText': {'text': "The Handmaid's Tale",
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2017,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 26,
#        'year': 2017,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2956627714',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMWIxMzk4NmItZmM1YS00ODUyLWFlNjgtZDQ4MzljZTZmZDQ5XkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 10,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt20214908',
#       'titleText': {'text': 'Another Simple Favor', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Another Simple Favor',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 1,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4038432514',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDBhNTg1MWMtMDc5Ni00YTk1LWFjNGUtMmE2Y2Q5MGQ2M2Q2XkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30459041',
#       'titleText': {'text': 'Your Friends & Neighbors',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Your Friends & Neighbors',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm662472962',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmJkNGYzOGQtMDk5My00MTgzLThiMzMtZGVkZTZmNmYxNzU1XkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 11,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt8634332',
#       'titleText': {'text': 'The Righteous Gemstones',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Righteous Gemstones',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2019,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 8,
#        'day': 18,
#        'year': 2019,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2076871170',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMjM3ZWQ1YWQtNGRiZi00ZDQ0LWJhMzgtNTNlMjFjYzU4NWQwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 12,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14123284',
#       'titleText': {'text': 'Havoc', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Havoc', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 25,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm441680642',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZWJjMjdhNGEtZjEyMi00OTg2LTllMzQtN2JlZWNjYzI4YzFhXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7587890',
#       'titleText': {'text': 'The Rookie', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Rookie', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2018,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 10,
#        'day': 16,
#        'year': 2018,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm301496577',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMzc2MDdkZDUtZjZlYy00MGMyLWJkNzUtMTMxY2FkZjZjYmEyXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 13,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}}]}}}

# %%
nodes = api_data.get('data',{}).get('topMeterTitles',{}).get('edges',{})
nodes[0].get('node')
# Out:
# {'__typename': 'Title',
#  'id': 'tt3581920',
#  'titleText': {'text': 'The Last of Us', 'isOriginalTitle': True},
#  'originalTitleText': {'text': 'The Last of Us', 'isOriginalTitle': True},
#  'releaseYear': {'__typename': 'YearRange', 'year': 2023, 'endYear': None},
#  'releaseDate': {'__typename': 'ReleaseDate',
#   'month': 1,
#   'day': 15,
#   'year': 2023,
#   'country': {'id': 'US'},
#   'restriction': None,
#   'attributes': [{'id': 'internet', 'text': 'internet'}],
#   'displayableProperty': {'qualifiersInMarkdownList': None}},
#  'titleType': {'__typename': 'TitleType',
#   'id': 'tvSeries',
#   'text': 'TV Series',
#   'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#   'canHaveEpisodes': True,
#   'isEpisode': False,
#   'isSeries': True,
#   'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#  'primaryImage': {'__typename': 'Image',
#   'id': 'rm2670496002',
#   'url': 'https://m.media-amazon.com/images/M/MV5BYWI3ODJlMzktY2U5NC00ZjdlLWE1MGItNWQxZDk3NWNjN2RhXkEyXkFqcGc@._V1_.jpg',
#   'height': 2048,
#   'width': 1383},
#  'meterRanking': {'__typename': 'TitleMeterRanking',
#   'currentRank': 1,
#   'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}

# %%
nodes = api_data.get('data',{}).get('topMeterTitles',{}).get('edges',{})
popular_movie_data = []
for nd in nodes:
    node = nd.get('node',{})
    title = node.get('titleText',{}).get('text',{})
    year = node.get('releaseYear',{}).get('year',{})
    ranks = node.get('meterRanking',{}).get('currentRank',{})
    #print(title,year,ranks)
    popular_movie_data.append([title,year,ranks])
print(popular_movie_data)
# Out:
# [['The Last of Us', 2023, 1], ['Thunderbolts*', 2025, 1], ['Andor', 2022, 2], ['The Four Seasons', 2025, 3], ['Sinners', 2025, 2], ['Black Mirror', 2011, 4], ['MobLand', 2025, 5], ['You', 2018, 6], ['Nonnas', 2025, 3], ['The Eternaut', 2025, 7], ['Conclave', 2024, 4], ['The White Lotus', 2021, 8], ['Warfare', 2025, 5], ['Poker Face', 2023, 9], ["The Handmaid's Tale", 2017, 10], ['Another Simple Favor', 2025, 6], ['Your Friends & Neighbors', 2025, 11], ['The Righteous Gemstones', 2019, 12], ['Havoc', 2025, 7], ['The Rookie', 2018, 13]]

# %%
# to save the above results to a csv file
import csv
with open("Top_movies.csv","w",encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Movie Titles","Release Year","Rank"]) # represents the column names
    writer.writerows(popular_movie_data) # represents rows of data being inserted

# %% [markdown]
# ### API PROJECT

# %%
import requests,csv

# %%
#Load the API key from .env file
# %pip install python-dotenv requests
# Out:
# Requirement already satisfied: python-dotenv in d:\teju\adv python\repository\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: requests in d:\teju\adv python\repository\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\teju\adv python\repository\venv\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the API key from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("API_KEY")

# %%
class api_extracter:

    # create instance attributes
    def __init__(self,api_key):
        self.api_key = api_key
    
    def get_data(self):

        url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

        querystring = {"limit":"20","topMeterTitlesType":"ALL"}

        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "imdb232.p.rapidapi.com"
        }

        response = requests.get(url, headers=headers, params=querystring)

        api_data = response.json()
        
        nodes = api_data.get('data',{}).get('topMeterTitles',{}).get('edges',{})
        popular_movie_data = []
        for nd in nodes:
            node = nd.get('node',{})
            title = node.get('titleText',{}).get('text',{})
            year = node.get('releaseYear',{}).get('year',{})
            ranks = node.get('meterRanking',{}).get('currentRank',{})
            #print(title,year,ranks)
            popular_movie_data.append([title,year,ranks])
        
        return popular_movie_data
    
    def save_data(self):
        with open("Top_movies2.csv","w",encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(["Movie Titles","Release Year","Rank"]) # represents the column names
            writer.writerows(popular_movie_data) # represents rows of data being inserted
        print("File is saved successfully")

# %%
api1 = api_extracter(api_key)

# %%
data1 = api1.get_data()
data1
# Out:
# [['The Last of Us', 2023, 1],
#  ['Thunderbolts*', 2025, 1],
#  ['Andor', 2022, 2],
#  ['The Four Seasons', 2025, 3],
#  ['Sinners', 2025, 2],
#  ['Black Mirror', 2011, 4],
#  ['MobLand', 2025, 5],
#  ['You', 2018, 6],
#  ['Nonnas', 2025, 3],
#  ['The Eternaut', 2025, 7],
#  ['Conclave', 2024, 4],
#  ['The White Lotus', 2021, 8],
#  ['Warfare', 2025, 5],
#  ['Poker Face', 2023, 9],
#  ["The Handmaid's Tale", 2017, 10],
#  ['Another Simple Favor', 2025, 6],
#  ['Your Friends & Neighbors', 2025, 11],
#  ['The Righteous Gemstones', 2019, 12],
#  ['Havoc', 2025, 7],
#  ['The Rookie', 2018, 13]]

# %%
api1.save_data()
# Out:
# File is saved successfully
