# %% [markdown]
# ## Python-SQL coneection

# %%
# %pip install sqlalchemy ipython-sql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 16.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ----- ---------------------------------- 2.4/16.4 MB 22.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.5/16.4 MB 14.0 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/16.4 MB 9.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/16.4 MB 8.5 MB/s eta 0:00:02
#    ------------------ --------------------- 7.6/16.4 MB 7.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.9/16.4 MB 7.1 MB/s eta 0:00:02
#    ------------------- -------------------- 8.1/16.4 MB 6.5 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.4 MB 5.8 MB/s eta 0:00:02
#    --------------------- ------------------ 8.9/16.4 MB 4.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.4 MB 4.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.7/16.4 MB 4.4 MB/s eta 0:00:02
# ...

# %%
# %pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Restart the kernel

# %%
import pandas as pd

# %%
from sqlalchemy import URL,create_engine

# %%
conn_str = URL.create(
    drivername="mysql+pymysql",
    username = "root",
    password = "tejaswini1994",
    host = "localhost",
    port = 3306,
    database="tejaswini123"
)

# %%
engine = create_engine(conn_str)

# %% [markdown]
# ## Reading data from mysql database

# %%
conn = engine.connect()
# to view all the tables present in tejaswini123
pd.read_sql("show tables",conn)
# Out:
#    Tables_in_tejaswini123
# 0                athletes
# 1             course_data
# 2                 courses
# 3               customers
# 4              department
# 5                    dept
# 6                dept_123
# 7                  dept_2
# 8                  dept_3
# 9                  drinks
# 10                   emp3
# 11                emp_123
# 12                empdata
# 13                   empl
# 14               employee
# 15                  marks
# 16                 snacks
# 17               startups
# 18                   tips
# 19                  users
# 20                 users2

# %%
# to extract customers tables information from weekday911 databse
df = pd.read_sql("select * from emp3",conn)
df
# Out:
#    Id       FullName   Salary  ManagerId
# 0   1     John Smith  10000.0        3.0
# 1   2  Jane Anderson  12000.0        3.0
# 2   3      Tom Lanon  15000.0        4.0
# 3   4    Anne Connor  20000.0        NaN
# 4   5    Jeremy York   9000.0        1.0

# %%
# to extract FullName,Salary from emp3 table 
df1 = pd.read_sql("select FullName,Salary from emp3",conn)
df1
# Out:
#         FullName   Salary
# 0     John Smith  10000.0
# 1  Jane Anderson  12000.0
# 2      Tom Lanon  15000.0
# 3    Anne Connor  20000.0
# 4    Jeremy York   9000.0

# %% [markdown]
# ## to write/save the tables to mysql databases

# %%
# to push the data to mysql database
df1.to_sql("emp3_data_new",conn,if_exists='replace')
# Out:
# 5

# %%
pd.read_sql("show tables",conn)
# Out:
#    Tables_in_tejaswini123
# 0                athletes
# 1             course_data
# 2                 courses
# 3               customers
# 4              department
# 5                    dept
# 6                dept_123
# 7                  dept_2
# 8                  dept_3
# 9                  drinks
# 10                   emp3
# 11          emp3_data_new
# 12                emp_123
# 13                empdata
# 14                   empl
# 15               employee
# 16                  marks
# 17                 snacks
# 18               startups
# 19                   tips
# 20                  users
# 21                 users2
